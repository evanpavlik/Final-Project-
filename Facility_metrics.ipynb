# %% [markdown]
# # Facilitiy metrics
# I analyzed the ammount of public facilities each neighborhood had, using the Allegheny County Human Services Community Profiles

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/Users/zanderhodgson/Downloads/33490823-a68e-40ce-b22d-cd7e03f0f2b2.csv")
df.head(90)
# Out:
#         _id metric_name      report_group  calendar_year  kpi_count  \
# 0   1009075   Overdoses  Community Trends           2020        NaN
# 1   1009076   Overdoses  Community Trends           2021        NaN
# 2   1009077   Overdoses  Community Trends           2022        NaN
# 3   1009078   Overdoses  Community Trends           2023        NaN
# 4   1009079   Overdoses  Community Trends           2024        NaN
# ..      ...         ...               ...            ...        ...
# 85  1009160   Overdoses  Community Trends           2021        NaN
# 86  1009161   Overdoses  Community Trends           2022        NaN
# 87  1009162   Overdoses  Community Trends           2023        NaN
# 88  1009163   Overdoses  Community Trends           2024        NaN
# 89  1009164   Overdoses  Community Trends           2025        NaN
#
#            geo_area_name
# 0       Allegheny Center
# 1       Allegheny Center
# 2       Allegheny Center
# 3       Allegheny Center
# ...

# %%
counts = df["metric_name"].value_counts()
counts.head(90)
# Out:
# metric_name
# Children and Parents Receiving Child Welfare Services         546
# Individuals Receiving Income Supports                         546
# Individuals Receiving Homelessness and Housing Services       546
# Individuals Receiving Mental Health Services                  546
# Individuals Receiving Family Strengthening Programs           546
# Children Receiving DHS-Funded Out of School Programs          546
# Children Attending Early Childhood Programs Managed by DHS    546
# Individuals Receiving DHS Services                            546
# Older Adults Receiving Services                               546
# Jail Population                                               546
# Involuntary Commitments                                       546
# Homeless Population                                           540
# Individuals Receiving Substance Use Disorder Services         540
# Children Receiving Early Intervention Services                537
# ...

# %% [markdown]
# I just want to see the ammount of services provided right now, so we can filter out the "community trends" like jail population and overdoses

# %%
counted = newdf["geo_area_name"].value_counts()
counted.head(90)
# Out:
# geo_area_name
# Allegheny Center     72
# Perry North          72
# Oakwood              72
# Northview Heights    72
# Mount Washington     72
#                      ..
# Strip District       66
# Allegheny West       60
# South Shore          60
# Chateau              60
# X-Unassigned         60
# Name: count, Length: 90, dtype: int64

# %%
plt.figure(figsize=(15,5))
counted.plot(kind="bar")
plt.title("Ammount of services per Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Ammount of services")
plt.tight_layout()
plt.show()
